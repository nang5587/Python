# %% [markdown]
# ## 변수

# %%
a = 1
print(type(a), a)
a = 1.2
print(type(a),a)
a = True
print(type(a),a)
a = [1,2]
print(type(a),a)
a = (1,2)
print(type(a),a)
a = lambda x:5
print(type(a),a)
a
# Out:
# <class 'int'> 1
# <class 'float'> 1.2
# <class 'bool'> True
# <class 'list'> [1, 2]
# <class 'tuple'> (1, 2)
# <class 'function'> <function <lambda> at 0x0000025E57AD4F70>
# <function __main__.<lambda>(x)>

# %%
a,b = 5,2
print(a+b, a-b, a/b, a*b, a%b)
# Out:
# 7 3 2.5 10 1

# %% [markdown]
# ## 조건문

# %%
age = 20
if age < 20:
    print('미성년자')
else: 
    print('성인')
# Out:
# 성인

# %%
n = 15
if n % 3 == 0 and n % 5 == 0:
    print("multiple")
else:
    # else 조건 모르겠으면 pass
    print("not multiple")
    pass
# Out:
# multiple

# %%
age = 25
if 20 < age < 30:
    print('right')
# Out:
# right

# %% [markdown]
# ## 반복문

# %%
lst = [1,2,3]
for i in lst:
    print(i)
# Out:
# 1
# 2
# 3

# %%
lst = 'hello'
# lst[0] = 'k' string도 변경 불가
for i in lst:
    print(i)

for i in range(3):
    print(i)
# Out:
# h
# e
# l
# l
# o
# 0
# 1
# 2

# %%
lst = (1,2,3)
for i in lst:
    print(i)
# 안의 값의 변경이 불가능한 튜플
# Out:
# 1
# 2
# 3

# %%
d = {1:'a', 2:'b', 3:'c'}
d[4] = 'd'
print(type(d),d)

for k, v in d.items():
    print(k,v)
# Out:
# <class 'dict'> {1: 'a', 2: 'b', 3: 'c', 4: 'd'}
# 1 a
# 2 b
# 3 c
# 4 d

# %%
a = list((1,2,3))
print(a)
# Out:
# [1, 2, 3]

# %%
a = list(range(0,3))
print(a)
# Out:
# [0, 1, 2]

# %%
lst = [1,2,3]
lst.append(4)
lst
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ## 함수

# %%
def add(a,b):
    return a+b

add(1,2)
# Out:
# 3

# %%
n = 5
data = "1 2 3 4 5"
d = list(map(int, data.split()))
type(d[0])
# Out:
# int

# %%
n = 5
data = "1 2 3"
a,b,c = map(int, data.split())
a,b,c
# Out:
# (1, 2, 3)

# %%
def add_sub(a,b):
    return a+b, a-b

add_sub(1,2)
# Out:
# (3, -1)

# %%
a, b =1,2
a,b = b,a
print(a,b)
# Out:
# 2 1

# %%
def add(a:int,b:int) -> int:
    return a+b
add(3,5)
# Out:
# 8

# %%
import typing

def add(a:int,b:int) -> int:
    return a+b
add(3,5)
# Out:
# 8

# %%
def add_sub(a,b=4):
    return a+b, a-b

a,b = add_sub(2,4)
print(a,b)

a, b = add_sub(5)
print(a,b)
# Out:
# 6 -2
# 9 1

# %%
data = (1,2)
add_sub(*data)
# Out:
# (3, -1)

# %%
d = {'a': 1, 'b':2}
add_sub(**d)
# Out:
# (3, -1)

# %%
s = 'hello'
len(s)
# Out:
# 5

# %%
len([1,2,3])
# Out:
# 3

# %%
data = [1,2,3]
sum(data)
# Out:
# 6

# %%
data = (2,3,1)
print(sorted(data), data)
# sorted는 원본을 수정하지 않고 새로운 것을 만든다
# Out:
# [1, 2, 3] (2, 3, 1)

# %%
print(data.sort(), data)
# .sort()는 원본을 가지고 만든다
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(data.sort(), data)
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %%
import math

math.exp(2)
# Out:
# 7.38905609893065

# %%
math.log(2)
# Out:
# 0.6931471805599453

# %%
math.sin(2)
# Out:
# 0.9092974268256817

# %%
import numpy as np
