# %%
import pandas as pd

# %%
df = pd.read_csv('data/california_cities.csv')
df.head()
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          482 non-null    int64
#  1   city                482 non-null    object
#  2   latd                482 non-null    float64
#  3   longd               482 non-null    float64
#  4   elevation_m         434 non-null    float64
#  5   elevation_ft        470 non-null    float64
#  6   population_total    482 non-null    int64
#  7   area_total_sq_mi    480 non-null    float64
#  8   area_land_sq_mi     482 non-null    float64
#  9   area_water_sq_mi    481 non-null    float64
#  10  area_total_km2      477 non-null    float64
#  11  area_land_km2       478 non-null    float64
#  12  area_water_km2      478 non-null    float64
#  13  area_water_percent  477 non-null    float64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 52.8+ KB

# %%
df.tail()
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 477          98.0              2933             1.531            1.531
# 478        2582.0              7765            10.053            9.980
# 479          59.0             64925            14.656           14.578
# 480        2618.0             51367            27.893           27.888
# 481        3369.0             20700            40.015           40.015
#
#      area_water_sq_mi  area_total_km2  area_land_km2  area_water_km2  \
# 477             0.000           3.966          3.966           0.000
# ...

# %%
df.shape
# Out:
# (482, 14)

# %%
df.dropna().shape
# Out:
# (427, 14)

# %%
df.fillna(0).shape
# Out:
# (482, 14)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'city', 'latd', 'longd', 'elevation_m', 'elevation_ft',
#        'population_total', 'area_total_sq_mi', 'area_land_sq_mi',
#        'area_water_sq_mi', 'area_total_km2', 'area_land_km2', 'area_water_km2',
#        'area_water_percent'],
#       dtype='object')

# %%
cols = ['latd', 'longd', 'elevation_m', 'elevation_ft',
    'population_total', 'area_total_sq_mi', 'area_land_sq_mi',
    'area_water_sq_mi', 'area_total_km2', 'area_land_km2', 'area_water_km2',
    'area_water_percent']

# %%
df[cols].median()
# Out:
# latd                     36.204722
# longd                  -119.708611
# elevation_m              67.000000
# elevation_ft            200.000000
# population_total      29057.500000
# area_total_sq_mi          9.093000
# area_land_sq_mi           8.362000
# area_water_sq_mi          0.029000
# area_total_km2           23.551000
# area_land_km2            21.533000
# area_water_km2            0.078500
# area_water_percent        0.340000
# dtype: float64

# %%
df.fillna(df[cols].median())[:5]
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444         67.0          33.0
# 3           3       Albany  37.886944 -122.297778         67.0          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
# ...

# %%
df[cols].mean()
# Out:
# latd                     36.095088
# longd                  -119.837714
# elevation_m             180.416705
# elevation_ft            567.168723
# population_total      64894.933610
# area_total_sq_mi         18.442183
# area_land_sq_mi          16.840981
# area_water_sq_mi          1.589630
# area_total_km2           46.753283
# area_land_km2            43.547021
# area_water_km2            3.125178
# area_water_percent        5.301801
# dtype: float64

# %%
df[cols].fillna(df[cols].mean())
# Out:
#           latd       longd  elevation_m  elevation_ft  population_total  \
# 0    34.576111 -117.432778   875.000000        2871.0             31765
# 1    34.153333 -118.761667   281.000000         922.0             20330
# 2    37.756111 -122.274444   180.416705          33.0             75467
# 3    37.886944 -122.297778   180.416705          43.0             18969
# 4    34.081944 -118.135000   150.000000         492.0             83089
# ..         ...         ...          ...           ...               ...
# 477  38.403056 -122.362222    30.000000          98.0              2933
# 478  41.726667 -122.637500   787.000000        2582.0              7765
# 479  39.134722 -121.626111    18.000000          59.0             64925
# 480  34.030278 -117.048611   798.000000        2618.0             51367
# 481  34.133333 -116.416667  1027.000000        3369.0             20700
#
#      area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  area_total_km2  \
# ...

# %%
df.describe().T
# Out:
#                     count          mean            std         min  \
# Unnamed: 0          482.0    240.500000     139.285678    0.000000
# latd                482.0     36.095088       2.298006   32.578333
# longd               482.0   -119.837714       2.147676 -124.263333
# elevation_m         434.0    180.416705     309.531825  -34.000000
# elevation_ft        470.0    567.168723    1001.265722 -180.000000
# population_total    482.0  64894.933610  203204.096676    1.000000
# area_total_sq_mi    480.0     18.442183      36.363230    0.314000
# area_land_sq_mi     482.0     16.840981      32.694647    0.314000
# area_water_sq_mi    481.0      1.589630       9.490386    0.000000
# area_total_km2      477.0     46.753283      90.972269    0.813000
# area_land_km2       478.0     43.547021      84.933022    0.813000
# area_water_km2      478.0      3.125178      11.562269    0.000000
# area_water_percent  477.0      5.301801      14.656428    0.000000
#
# ...

# %%
import seaborn as sns

sns.pairplot(df)

# %%
df = df.fillna(df[cols].median())

# %%
df.to_csv('result.csv')

# %% [markdown]
# ## 2단계

# %%
df = pd.read_csv('result.csv')

df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0           0     Adelanto  34.576111 -117.432778        875.0
# 1             1           1  AgouraHills  34.153333 -118.761667        281.0
# 2             2           2      Alameda  37.756111 -122.274444         67.0
# 3             3           3       Albany  37.886944 -122.297778         67.0
# 4             4           4     Alhambra  34.081944 -118.135000        150.0
#
#    elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0        2871.0             31765            56.027           56.009
# 1         922.0             20330             7.822            7.793
# 2          33.0             75467            22.960           10.611
# 3          43.0             18969             5.465            1.788
# 4         492.0             83089             7.632            7.631
#
#    area_water_sq_mi  area_total_km2  area_land_km2  area_water_km2  \
# ...

# %%
import numpy as np

c1 = pd.Series([1,2,3])
type(c1), type(c1.values), type(df['latd'])
# Out:
# (pandas.core.series.Series, numpy.ndarray, pandas.core.series.Series)

# %%
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
idx = pd.Index([1,2,3])
idx[1] = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 idx = pd.Index([1,2,3])
# ----> 2 idx[1] = 2
#
# File ~\AppData\Local\Programs\Python\Python39\Lib\site-packages\pandas\core\indexes\base.py:5371, in Index.__setitem__(self, key, value)
#    5369 @final
#    5370 def __setitem__(self, key, value) -> None:
# -> 5371     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
df.index
# Out:
# RangeIndex(start=0, stop=482, step=1)

# %%
df['latd'].
# Out:
#   Cell In[35], line 1
#     df['latd'].
#                ^
# SyntaxError: invalid syntax

# %%
df.loc[:, ['latd', 'longd']]
# Out:
#           latd       longd
# 0    34.576111 -117.432778
# 1    34.153333 -118.761667
# 2    37.756111 -122.274444
# 3    37.886944 -122.297778
# 4    34.081944 -118.135000
# ..         ...         ...
# 477  38.403056 -122.362222
# 478  41.726667 -122.637500
# 479  39.134722 -121.626111
# 480  34.030278 -117.048611
# 481  34.133333 -116.416667
#
# [482 rows x 2 columns]

# %%
df.index.is_monotonic_increasing
# Out:
# True

# %%
df.iloc[:, 2:4]
# Out:
#             city       latd
# 0       Adelanto  34.576111
# 1    AgouraHills  34.153333
# 2        Alameda  37.756111
# 3         Albany  37.886944
# 4       Alhambra  34.081944
# ..           ...        ...
# 477   Yountville  38.403056
# 478        Yreka  41.726667
# 479     YubaCity  39.134722
# 480      Yucaipa  34.030278
# 481  YuccaValley  34.133333
#
# [482 rows x 2 columns]

# %%
(df[cols] / 5).index, df.index
# Out:
# (RangeIndex(start=0, stop=482, step=1), RangeIndex(start=0, stop=482, step=1))

# %%
df.sort_index()
# Out:
#      Unnamed: 0.1  Unnamed: 0         city       latd       longd  \
# 0               0           0     Adelanto  34.576111 -117.432778
# 1               1           1  AgouraHills  34.153333 -118.761667
# 2               2           2      Alameda  37.756111 -122.274444
# 3               3           3       Albany  37.886944 -122.297778
# 4               4           4     Alhambra  34.081944 -118.135000
# ..            ...         ...          ...        ...         ...
# 477           477         477   Yountville  38.403056 -122.362222
# 478           478         478        Yreka  41.726667 -122.637500
# 479           479         479     YubaCity  39.134722 -121.626111
# 480           480         480      Yucaipa  34.030278 -117.048611
# 481           481         481  YuccaValley  34.133333 -116.416667
#
#      elevation_m  elevation_ft  population_total  area_total_sq_mi  \
# 0          875.0        2871.0             31765            56.027
# ...

# %%
df.sort_values(['city'])
# Out:
#      Unnamed: 0.1  Unnamed: 0         city       latd       longd  \
# 0               0           0     Adelanto  34.576111 -117.432778
# 1               1           1  AgouraHills  34.153333 -118.761667
# 2               2           2      Alameda  37.756111 -122.274444
# 3               3           3       Albany  37.886944 -122.297778
# 4               4           4     Alhambra  34.081944 -118.135000
# ..            ...         ...          ...        ...         ...
# 477           477         477   Yountville  38.403056 -122.362222
# 478           478         478        Yreka  41.726667 -122.637500
# 479           479         479     YubaCity  39.134722 -121.626111
# 480           480         480      Yucaipa  34.030278 -117.048611
# 481           481         481  YuccaValley  34.133333 -116.416667
#
#      elevation_m  elevation_ft  population_total  area_total_sq_mi  \
# 0          875.0        2871.0             31765            56.027
# ...

# %%
# select *
# from df
# where latd > 5
# order by latd, longd;

df.loc[df['latd']>5, :].sort_values(['latd', 'longd'])
# Out:
#      Unnamed: 0.1  Unnamed: 0           city       latd       longd  \
# 186           186         186  ImperialBeach  32.578333 -117.117222
# 74             74          74     ChulaVista  32.627778 -117.048056
# 93             93          93       Coronado  32.678056 -117.172500
# 280           280         280   NationalCity  32.678056 -117.099167
# 54             54          54       Calexico  32.678889 -115.498889
# ..            ...         ...            ...        ...         ...
# 478           478         478          Yreka  41.726667 -122.637500
# 265           265         265       Montague  41.727222 -122.526389
# 98             98          98   CrescentCity  41.755833 -124.201667
# 438           438         438       Tulelake  41.954167 -121.475833
# 114           114         114         Dorris  41.965000 -121.918889
#
#      elevation_m  elevation_ft  population_total  area_total_sq_mi  \
# 186         21.0          69.0             26324             4.485
# ...

# %%
df.loc[df['latd']>5, ['latd', 'longd', 'elevation_m']].sort_values(['latd', 'longd'])
# Out:
#           latd       longd  elevation_m
# 186  32.578333 -117.117222         21.0
# 74   32.627778 -117.048056         21.0
# 93   32.678056 -117.172500          6.0
# 280  32.678056 -117.099167         21.0
# 54   32.678889 -115.498889         67.0
# ..         ...         ...          ...
# 478  41.726667 -122.637500        787.0
# 265  41.727222 -122.526389        774.0
# 98   41.755833 -124.201667         67.0
# 438  41.954167 -121.475833       1230.0
# 114  41.965000 -121.918889       1294.0
#
# [482 rows x 3 columns]

# %%
df.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 477    0
# 478    0
# 479    0
# 480    0
# 481    0
# Length: 482, dtype: int64

# %%
df.notnull().sum(axis=1)
# Out:
# 0      15
# 1      15
# 2      15
# 3      15
# 4      15
#        ..
# 477    15
# 478    15
# 479    15
# 480    15
# 481    15
# Length: 482, dtype: int64

# %%
data = pd.Series([1,np.nan, 'hello', None])
data.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4 entries, 0 to 3
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 2 non-null      object
# dtypes: object(1)
# memory usage: 160.0+ bytes

# %%
data
# Out:
# 0        1
# 1      NaN
# 2    hello
# 3     None
# dtype: object

# %%
data[data.isnull()]
# Out:
# 1     NaN
# 3    None
# dtype: object

# %%
pop = pd.read_csv('data/state-population.csv')
areas = pd.read_csv('data/state-areas.csv')
abbrevs = pd.read_csv('data/state-abbrevs.csv')

pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
areas.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
abbrevs.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2544 entries, 0 to 2543
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state/region  2544 non-null   object
#  1   ages          2544 non-null   object
#  2   year          2544 non-null   int64
#  3   population    2524 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 79.6+ KB

# %%
areas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          52 non-null     object
#  1   area (sq. mi)  52 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 960.0+ bytes

# %%
abbrevs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         51 non-null     object
#  1   abbreviation  51 non-null     object
# dtypes: object(2)
# memory usage: 944.0+ bytes

# %%
# select *
# from area, abbrevs
# where area.state = abbrevs.state

# %%
#select *
#from area inner join state
# on area.state = state.state

# %%
merged = pd.merge(areas, abbrevs, how='inner', left_on='state', right_on='state')
merged
# Out:
#                    state  area (sq. mi) abbreviation
# 0                Alabama          52423           AL
# 1                 Alaska         656425           AK
# 2                Arizona         114006           AZ
# 3               Arkansas          53182           AR
# 4             California         163707           CA
# 5               Colorado         104100           CO
# 6            Connecticut           5544           CT
# 7               Delaware           1954           DE
# 8                Florida          65758           FL
# 9                Georgia          59441           GA
# 10                Hawaii          10932           HI
# 11                 Idaho          83574           ID
# 12              Illinois          57918           IL
# 13               Indiana          36420           IN
# 14                  Iowa          56276           IA
# 15                Kansas          82282           KS
# 16              Kentucky          40411           KY
# ...

# %%
merged = pd.merge(areas, abbrevs, how='outer', left_on='state', right_on='state')
merged
# Out:
#                    state  area (sq. mi) abbreviation
# 0                Alabama          52423           AL
# 1                 Alaska         656425           AK
# 2                Arizona         114006           AZ
# 3               Arkansas          53182           AR
# 4             California         163707           CA
# 5               Colorado         104100           CO
# 6            Connecticut           5544           CT
# 7               Delaware           1954           DE
# 8   District of Columbia             68           DC
# 9                Florida          65758           FL
# 10               Georgia          59441           GA
# 11                Hawaii          10932           HI
# 12                 Idaho          83574           ID
# 13              Illinois          57918           IL
# 14               Indiana          36420           IN
# 15                  Iowa          56276           IA
# 16                Kansas          82282           KS
# ...

# %%
#select *
#from pop outer join on pop.'state/region' = abbrevs.abbreviation
# on area.state = state.state

# %%
merged = pd.merge(pop, abbrevs, how='outer', left_on='state/region', right_on='abbreviation')
merged = merged.drop('abbreviation', axis=1)
merged.head()
# Out:
#   state/region     ages  year  population   state
# 0           AK    total  1990    553290.0  Alaska
# 1           AK  under18  1990    177502.0  Alaska
# 2           AK    total  1992    588736.0  Alaska
# 3           AK  under18  1991    182180.0  Alaska
# 4           AK  under18  1992    184878.0  Alaska

# %%
merged.isnull().any()
# Out:
# state/region    False
# ages            False
# year            False
# population       True
# state            True
# dtype: bool

# %%
merged[merged['population'].isnull()].head()
# Out:
#      state/region     ages  year  population state
# 1872           PR  under18  1990         NaN   NaN
# 1873           PR    total  1990         NaN   NaN
# 1874           PR    total  1991         NaN   NaN
# 1875           PR  under18  1991         NaN   NaN
# 1876           PR    total  1993         NaN   NaN

# %%
merged.loc[merged['state'].isnull(), 'state/region'].unique()
# Out:
# array(['PR', 'USA'], dtype=object)

# %%
merged.loc[merged['state/region'] == 'PR', 'state'] = 'Puerto Rico'
merged.loc[merged['state/region'] == 'USA', 'state'] = 'United States'
merged.isnull().any()
# Out:
# state/region    False
# ages            False
# year            False
# population       True
# state           False
# dtype: bool
