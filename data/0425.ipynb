# %%
import pandas as pd

df = pd.read_csv('weather_data/sitka_weather_2021_simple.csv')
df.head()
# Out:
#        STATION                  NAME        DATE  TAVG  TMAX  TMIN
# 0  USW00025333  SITKA AIRPORT, AK US  2021-01-01   NaN    44    40
# 1  USW00025333  SITKA AIRPORT, AK US  2021-01-02   NaN    44    35
# 2  USW00025333  SITKA AIRPORT, AK US  2021-01-03   NaN    43    36
# 3  USW00025333  SITKA AIRPORT, AK US  2021-01-04   NaN    45    39
# 4  USW00025333  SITKA AIRPORT, AK US  2021-01-05   NaN    45    40

# %%
import pandas as pd

df = pd.read_csv('weather_data/sitka_weather_2021_simple.csv')
df['TMAX'].values
# Out:
# array([44, 44, 43, 45, 45, 44, 48, 48, 46, 46, 44, 44, 39, 47, 48, 47, 46,
#        48, 42, 38, 41, 40, 38, 39, 37, 36, 30, 36, 40, 42, 43, 38, 38, 40,
#        39, 37, 37, 36, 30, 17, 30, 37, 39, 38, 37, 35, 38, 43, 43, 42, 44,
#        44, 42, 38, 39, 42, 43, 44, 45, 41, 41, 41, 43, 43, 43, 47, 40, 41,
#        40, 41, 37, 35, 34, 40, 42, 43, 40, 37, 39, 43, 42, 42, 40, 41, 42,
#        39, 41, 41, 41, 41, 36, 38, 41, 41, 40, 38, 41, 39, 39, 36, 41, 41,
#        45, 45, 48, 50, 56, 67, 61, 51, 57, 52, 63, 60, 53, 50, 51, 48, 47,
#        48, 50, 49, 48, 55, 63, 56, 50, 49, 52, 49, 49, 47, 49, 48, 49, 52,
#        56, 57, 52, 53, 49, 53, 50, 51, 51, 51, 49, 57, 58, 58, 56, 53, 51,
#        56, 58, 54, 58, 59, 53, 55, 59, 61, 67, 64, 58, 60, 66, 58, 68, 59,
#        55, 56, 63, 63, 59, 63, 78, 75, 61, 62, 61, 60, 66, 60, 65, 59, 58,
#        58, 57, 60, 60, 60, 57, 58, 60, 61, 63, 63, 70, 64, 59, 63, 61, 58,
# ...

# %%
import datetime as dt

dt.datetime.strptime('2025-04-25', '%Y-%m-%d')
# Out:
# datetime.datetime(2025, 4, 25, 0, 0)

# %%
str(dt.datetime.today())
dt.datetime.today().strftime('%Y-%m-%d')
# Out:
# '2025-04-25'

# %%
for i in range(100):
    print((dt.datetime.today() + dt.timedelta(days=1)).strftime('%Y-%m-%d'))
# Out:
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# 2025-04-26
# ...
